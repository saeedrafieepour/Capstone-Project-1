# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %%
import pandas as pd
import requests

# Check the end of the url -->                                                                             HERE --v
url = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"
#headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/114.0'}

resp = requests.get(url)
properties = pd.read_excel(resp.content, sheet_name='Average price', index_col= None, engine='openpyxl')
# Out:
# C:\Users\srafi\AppData\Local\Temp\ipykernel_3512\3122335220.py:9: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   properties = pd.read_excel(resp.content, sheet_name='Average price', index_col= None, engine='openpyxl')

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# 0    E12000002          E12000003     E12000004     E12000005       E12000006
# 1  43958.48001        44803.42878   45544.52227   48527.52339      56701.5961
# 2  43925.42289        44528.80721   46051.57066   49341.29029     56593.59475
# 3   44434.8681        45200.46775   45383.82395   49442.17973     56171.18278
# 4   44267.7796        45614.34341   46124.23045   49455.93299     56567.89582
#
#         LONDON   SOUTH EAST   SOUTH WEST Unnamed: 47      England
# 0    E12000007    E12000008    E12000009         NaN    E92000001
# 1  74435.76052  64018.87894   54705.1579         NaN  53202.77128
# 2  72777.93709  63715.02399  54356.14843         NaN   53096.1549
# 3  73896.84204  64113.60858  53583.07667         NaN   53201.2843
# 4  74455.28754  64623.22395  54786.01938         NaN   53590.8548
#
# [5 rows x 49 columns]

# %%
properties.sort_values("Unnamed: 0")
# Out:
#     Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 1   1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2   1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3   1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4   1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# 5   1995-05-01    84409.14932        53042.24852  90258.00033  63997.13588
# ..         ...            ...                ...          ...          ...
# 346 2023-10-01         866683             339090       582343       393681
# 347 2023-11-01         807979             342089       585717       396968
# 348 2023-12-01         738449             336162       579648       387785
# 349 2024-01-01         715466             322220       579029       391782
# 0          NaT      E09000001          E09000002    E09000003    E09000004
#
#            Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 1    71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2    72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3    72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4    72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
# 5    73704.04743  81542.61561  119929.2782   68844.9169  82077.05525  ...
# ..           ...          ...          ...          ...          ...  ...
# 346       535750       501839       846090       402680       527435  ...
# 347       529750       496876       828300       394945       514089  ...
# 348       510978       498636       857654       394355       522217  ...
# 349       532273       504764       797248       392498       515353  ...
# 0      E09000005    E09000006    E09000007    E09000008    E09000009  ...
#
#       NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS  \
# 1    43958.48001        44803.42878   45544.52227   48527.52339
# 2    43925.42289        44528.80721   46051.57066   49341.29029
# 3     44434.8681        45200.46775   45383.82395   49442.17973
# 4     44267.7796        45614.34341   46124.23045   49455.93299
# 5    44223.61973        44830.98563   45878.00396   50369.66188
# ..           ...                ...           ...           ...
# 346       215672             210289        244558        248177
# 347       215126             207852        245732        247958
# 348       216338             204984        243751        247293
# 349       215082             203571        240427        248758
# 0      E12000002          E12000003     E12000004     E12000005
#
#     EAST OF ENGLAND       LONDON   SOUTH EAST   SOUTH WEST Unnamed: 47  \
# 1        56701.5961  74435.76052  64018.87894   54705.1579         NaN
# 2       56593.59475  72777.93709  63715.02399  54356.14843         NaN
# 3       56171.18278  73896.84204  64113.60858  53583.07667         NaN
# 4       56567.89582  74455.28754  64623.22395  54786.01938         NaN
# 5       56479.80183  75432.02786  64530.36358  54698.83831         NaN
# ..              ...          ...          ...          ...         ...
# 346          340132       519429       379609       319462         NaN
# 347          342207       517123       380869       318179         NaN
# 348          332657       505075       371090       312200         NaN
# 349          336502       517726       373177       316879         NaN
# 0         E12000006    E12000007    E12000008    E12000009         NaN
#
#          England
# 1    53202.77128
# 2     53096.1549
# 3     53201.2843
# 4     53590.8548
# 5    53678.24041
# ..           ...
# 346       302363
# 347       302107
# 348       297463
# 349       298575
# 0      E92000001
#
# [350 rows x 49 columns]

# %%
properties_t = properties.transpose()
properties_t = properties_t.reset_index()
properties_t.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
# 3          90107.23471          91441.24768          92361.31512  ...
# 4          64252.32335          63722.70055          64432.60005  ...
#
#                    340                  341                  342  \
# 0  2023-04-01 00:00:00  2023-05-01 00:00:00  2023-06-01 00:00:00
# 1               860042               924796               956373
# 2               344644               345946               343422
# 3               589841               578152               573632
# 4               404180               399011               396593
#
#                    343                  344                  345  \
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00
# 1               935568               873432               851623
# 2               339647               340218               338040
# 3               577018               583840               587594
# 4               399113               397410               397784
#
#                    346                  347                  348  \
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00
# 1               866683               807979               738449
# 2               339090               342089               336162
# 3               582343               585717               579648
# 4               393681               396968               387785
#
#                    349
# 0  2024-01-01 00:00:00
# 1               715466
# 2               322220
# 3               579029
# 4               391782
#
# [5 rows x 351 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_t.columns = properties_t.iloc[0,:]
properties_t = properties_t.iloc[1:,:]
properties_t = properties_t.rename(columns = {"Unnamed: 0":"London Borough"})
properties_t.head()
# Out:
# 0      London Borough        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# 2         53700.34831         52113.12157         52232.19868  ...
# 3         90107.23471         91441.24768         92361.31512  ...
# 4         64252.32335         63722.70055         64432.60005  ...
# 5         74310.48167         74127.03788          73547.0411  ...
#
# 0 2023-04-01 00:00:00 2023-05-01 00:00:00 2023-06-01 00:00:00  \
# 1              860042              924796              956373
# 2              344644              345946              343422
# 3              589841              578152              573632
# 4              404180              399011              396593
# 5              516369              516138              516616
#
# 0 2023-07-01 00:00:00 2023-08-01 00:00:00 2023-09-01 00:00:00  \
# 1              935568              873432              851623
# 2              339647              340218              338040
# 3              577018              583840              587594
# 4              399113              397410              397784
# 5              510959              529255              531401
#
# 0 2023-10-01 00:00:00 2023-11-01 00:00:00 2023-12-01 00:00:00  \
# 1              866683              807979              738449
# 2              339090              342089              336162
# 3              582343              585717              579648
# 4              393681              396968              387785
# 5              535750              529750              510978
#
# 0 2024-01-01 00:00:00
# 1              715466
# 2              322220
# 3              579029
# 4              391782
# 5              532273
#
# [5 rows x 351 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_t = properties_t.rename(columns = {pd.NaT: "ID"})
properties_t.columns
# Out:
# Index([   'London Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-04-01 00:00:00, 2023-05-01 00:00:00, 2023-06-01 00:00:00,
#        2023-07-01 00:00:00, 2023-08-01 00:00:00, 2023-09-01 00:00:00,
#        2023-10-01 00:00:00, 2023-11-01 00:00:00, 2023-12-01 00:00:00,
#        2024-01-01 00:00:00],
#       dtype='object', name=0, length=351)

# %% [markdown]
# Subsetting the data to include only the London Borough

# %%
London_Borough = ["City of London", "Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Camden", "Croydon",\
                  "Ealing", "Enfield", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey", "Harrow", "Havering",\
                  "Hillingdon", "Hounslow", "Islington", "Kensington & Chelsea", "Kingston upon Thames", "Lambeth", "Lewisham",\
                  "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Southwark", "Sutton", "Tower Hamlets",\
                  "Waltham Forest", "Wandsworth", "Westminster"]
properties_t = properties_t.loc[properties_t["London Borough"].isin(London_Borough),:]
properties_t.shape
# Out:
# (33, 351)

# %% [markdown]
# Checking if there is any null in the data

# %%
properties_t.isna().sum().head(33)
# Out:
# 0
# London Borough         0
# ID                     0
# 1995-01-01 00:00:00    0
# 1995-02-01 00:00:00    0
# 1995-03-01 00:00:00    0
# 1995-04-01 00:00:00    0
# 1995-05-01 00:00:00    0
# 1995-06-01 00:00:00    0
# 1995-07-01 00:00:00    0
# 1995-08-01 00:00:00    0
# 1995-09-01 00:00:00    0
# 1995-10-01 00:00:00    0
# 1995-11-01 00:00:00    0
# 1995-12-01 00:00:00    0
# 1996-01-01 00:00:00    0
# 1996-02-01 00:00:00    0
# 1996-03-01 00:00:00    0
# 1996-04-01 00:00:00    0
# 1996-05-01 00:00:00    0
# 1996-06-01 00:00:00    0
# 1996-07-01 00:00:00    0
# 1996-08-01 00:00:00    0
# 1996-09-01 00:00:00    0
# 1996-10-01 00:00:00    0
# 1996-11-01 00:00:00    0
# 1996-12-01 00:00:00    0
# 1997-01-01 00:00:00    0
# 1997-02-01 00:00:00    0
# 1997-03-01 00:00:00    0
# 1997-04-01 00:00:00    0
# 1997-05-01 00:00:00    0
# 1997-06-01 00:00:00    0
# 1997-07-01 00:00:00    0
# dtype: int64

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_t = pd.melt(properties_t, id_vars= ["London Borough", "ID"], var_name="month", value_name = "price")
properties_t.head()
# Out:
#        London Borough         ID                month        price
# 0      City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 2              Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 3              Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 4               Brent  E09000005  1995-01-01 00:00:00  71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11517 entries, 0 to 11516
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London Borough  11517 non-null  object
#  1   ID              11517 non-null  object
#  2   month           11517 non-null  object
#  3   price           11517 non-null  object
# dtypes: object(4)
# memory usage: 360.0+ KB

# %%
properties_t["price"] = properties_t["price"].astype(float)
type(properties_t)
properties_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11517 entries, 0 to 11516
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London Borough  11517 non-null  object
#  1   ID              11517 non-null  object
#  2   month           11517 non-null  object
#  3   price           11517 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 360.0+ KB

# %%
properties_t.sort_values(["price", "London Borough"], ascending = [False, False]).head(10)
# Out:
#              London Borough         ID                month        price
# 10612  Kensington & Chelsea  E09000020  2021-10-01 00:00:00  1527601.000
# 10975  Kensington & Chelsea  E09000020  2022-09-01 00:00:00  1527039.000
# 10876  Kensington & Chelsea  E09000020  2022-06-01 00:00:00  1520758.000
# 10843  Kensington & Chelsea  E09000020  2022-05-01 00:00:00  1518352.000
# 10942  Kensington & Chelsea  E09000020  2022-08-01 00:00:00  1517723.000
# 10579  Kensington & Chelsea  E09000020  2021-09-01 00:00:00  1515740.000
# 10810  Kensington & Chelsea  E09000020  2022-04-01 00:00:00  1513572.000
# 10909  Kensington & Chelsea  E09000020  2022-07-01 00:00:00  1503688.000
# 9127   Kensington & Chelsea  E09000020  2018-01-01 00:00:00  1463377.921
# 10645  Kensington & Chelsea  E09000020  2021-11-01 00:00:00  1447296.000

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
import datetime
properties_t['month'] = pd.to_datetime(properties_t['month'])
properties_t["year"] = properties_t['month'].dt.year
print(type(properties_t))
properties_t.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        London Borough         ID      month        price  year
# 0      City of London  E09000001 1995-01-01  91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660  1995
# 2              Barnet  E09000003 1995-01-01  93284.51832  1995
# 3              Bexley  E09000004 1995-01-01  64958.09036  1995
# 4               Brent  E09000005 1995-01-01  71306.56698  1995

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
clean_data = properties_t

# %%
xc = clean_data.loc[clean_data["London Borough"] == "Kensington & Chelsea",:]["month"]
xc.shape
# Out:
# (349,)

# %%
yc = clean_data.loc[clean_data["London Borough"] == "Kensington & Chelsea",:]["price"]
yc.shape
# Out:
# (349,)

# %%
xc = clean_data.loc[clean_data["London Borough"] == "Kensington & Chelsea"]["month"]
yc = clean_data.loc[clean_data["London Borough"] == "Kensington & Chelsea"]["price"]
plt.plot(xc, yc)

xb = clean_data.loc[clean_data["London Borough"] == "Hackney",:]["month"]
yb = clean_data.loc[clean_data["London Borough"] == "Hackney",:]["price"]
plt.plot(xb, yb)
plt.legend(["Kensington & Chelsea", "Hackney"])

# %%
clean_data
# Out:
#            London Borough         ID      month         price  year
# 0          City of London  E09000001 1995-01-01   91448.98487  1995
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 2                  Barnet  E09000003 1995-01-01   93284.51832  1995
# 3                  Bexley  E09000004 1995-01-01   64958.09036  1995
# 4                   Brent  E09000005 1995-01-01   71306.56698  1995
# ...                   ...        ...        ...           ...   ...
# 11512              Sutton  E09000029 2024-01-01  420223.00000  2024
# 11513       Tower Hamlets  E09000030 2024-01-01  480719.00000  2024
# 11514      Waltham Forest  E09000031 2024-01-01  503705.00000  2024
# 11515          Wandsworth  E09000032 2024-01-01  612612.00000  2024
# 11516         Westminster  E09000033 2024-01-01  936715.00000  2024
#
# [11517 rows x 5 columns]

# %%
Average_price = clean_data.groupby(by = ["London Borough", "year"])['price'].mean()
print(Average_price.sample(10))
type(Average_price)
# Out:
# London Borough        year
# Tower Hamlets         1995     63652.446010
# Redbridge             2011    261965.535417
# Richmond upon Thames  2009    369390.075467
# Merton                2017    512185.807217
# Kingston upon Thames  2021    511703.750000
# Lewisham              2013    260815.066433
# Enfield               2001    135713.171425
# Greenwich             2017    391749.944825
# Waltham Forest        2007    237017.267950
# City of London        2005    311783.670592
# Name: price, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
Average_price = Average_price.reset_index()

# %%
xc = Average_price.loc[Average_price["London Borough"] == "Kensington & Chelsea"]["year"]
yc = Average_price.loc[Average_price["London Borough"] == "Kensington & Chelsea"]["price"]
plt.plot(xc, yc)

xb = Average_price.loc[Average_price["London Borough"] == "Hackney",:]["year"]
yb = Average_price.loc[Average_price["London Borough"] == "Hackney",:]["price"]
plt.plot(xb, yb)
plt.legend(["Kensington & Chelsea", "Hackney"])
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.show()

# %%
final ={}
for item in London_Borough:
    x  = Average_price[Average_price["London Borough"]== item]["year"]
    y  = Average_price[Average_price["London Borough"]== item] ["price"]
    X = pd.DataFrame(x)
    Y = pd.DataFrame(y)
    final[item] = Y.iloc[-1]/Y.iloc[0]
    plt.plot(x, y)
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.legend(["City of London", "Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Camden", "Croydon",\
                  "Ealing", "Enfield", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey", "Harrow", "Havering",\
                  "Hillingdon", "Hounslow", "Islington", "Kensington & Chelsea", "Kingston upon Thames", "Lambeth", "Lewisham",\
                  "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Southwark", "Sutton", "Tower Hamlets",\
                  "Waltham Forest", "Wandsworth", "Westminster"])
plt.show()
final
# Out:
# {'City of London': price    7.220729
#  dtype: float64,
#  'Barking & Dagenham': price    6.218306
#  dtype: float64,
#  'Barnet': price    6.308018
#  dtype: float64,
#  'Bexley': price    6.093835
#  dtype: float64,
#  'Brent': price    7.288432
#  dtype: float64,
#  'Bromley': price    6.158113
#  dtype: float64,
#  'Camden': price    6.623453
#  dtype: float64,
#  'Croydon': price    5.694704
#  dtype: float64,
#  'Ealing': price    6.345253
#  dtype: float64,
#  'Enfield': price    5.978656
#  dtype: float64,
#  'Greenwich': price    7.091079
#  dtype: float64,
#  'Hackney': price    9.056838
#  dtype: float64,
#  'Hammersmith & Fulham': price    5.880013
#  dtype: float64,
#  'Haringey': price    7.236038
#  dtype: float64,
#  'Harrow': price    6.019841
#  dtype: float64,
#  'Havering': price    6.140653
#  dtype: float64,
#  'Hillingdon': price    5.996373
#  dtype: float64,
#  'Hounslow': price    6.318928
#  dtype: float64,
#  'Islington': price    6.902407
#  dtype: float64,
#  'Kensington & Chelsea': price    6.207954
#  dtype: float64,
#  'Kingston upon Thames': price    6.530971
#  dtype: float64,
#  'Lambeth': price    7.569338
#  dtype: float64,
#  'Lewisham': price    7.387856
#  dtype: float64,
#  'Merton': price    7.043015
#  dtype: float64,
#  'Newham': price    7.328569
#  dtype: float64,
#  'Redbridge': price    6.589016
#  dtype: float64,
#  'Richmond upon Thames': price    6.80602
#  dtype: float64,
#  'Southwark': price    8.003728
#  dtype: float64,
#  'Sutton': price    5.978307
#  dtype: float64,
#  'Tower Hamlets': price    7.552247
#  dtype: float64,
#  'Waltham Forest': price    8.219732
#  dtype: float64,
#  'Wandsworth': price    6.896525
#  dtype: float64,
#  'Westminster': price    7.00666
#  dtype: float64}

# %%
x  = Average_price[Average_price["London Borough"]== item]["year"]
y  = Average_price[Average_price["London Borough"]== item] ["price"]

plt.plot(x, y)
plt.legend(item)
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.show()

# %%
Ratio = pd.DataFrame(final)
Ratio = Ratio.transpose()
Ratio = Ratio.rename(columns = {"price": "Ratio"})
Ratio_sorted = Ratio.sort_values("Ratio", ascending = False)
print(Ratio_sorted)
Ratio_sorted.describe()
# Out:
#                          Ratio
# Hackney               9.056838
# Waltham Forest        8.219732
# Southwark             8.003728
# Lambeth               7.569338
# Tower Hamlets         7.552247
# Lewisham              7.387856
# Newham                7.328569
# Brent                 7.288432
# Haringey              7.236038
# City of London        7.220729
# Greenwich             7.091079
# Merton                7.043015
# Westminster           7.006660
# Islington             6.902407
# Wandsworth            6.896525
# Richmond upon Thames  6.806020
# Camden                6.623453
# Redbridge             6.589016
# Kingston upon Thames  6.530971
# Ealing                6.345253
# Hounslow              6.318928
# Barnet                6.308018
# Barking & Dagenham    6.218306
# Kensington & Chelsea  6.207954
# Bromley               6.158113
# Havering              6.140653
# Bexley                6.093835
# Harrow                6.019841
# Hillingdon            5.996373
# Enfield               5.978656
# Sutton                5.978307
# Hammersmith & Fulham  5.880013
# Croydon               5.694704
#            Ratio
# count  33.000000
# mean    6.778533
# std     0.763880
# min     5.694704
# 25%     6.158113
# 50%     6.623453
# 75%     7.236038
# max     9.056838

# %%
Most_Increase_10 = Ratio_sorted.head(10)
Most_Increase_10
# Out:
#                    Ratio
# Hackney         9.056838
# Waltham Forest  8.219732
# Southwark       8.003728
# Lambeth         7.569338
# Tower Hamlets   7.552247
# Lewisham        7.387856
# Newham          7.328569
# Brent           7.288432
# Haringey        7.236038
# City of London  7.220729

# %%
Most_Increase_10.plot(kind = "bar", title = "London Borough Price Change Ratio")
# Out:
# <Axes: title={'center': 'London Borough Price Change Ratio'}>

# %%
Ratio.hist(bins = 4)
plt.legend("Price Change")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Average_price["ratio"] = 0
Average_price.sample(10)
# Out:
#      London Borough  year          price  ratio
# 820       Southwark  2005  224050.174675      0
# 554       Islington  2009  345284.435133      0
# 117           Brent  2022  528224.333333      0
# 688        Lewisham  2023  447610.250000      0
# 48           Barnet  2013  374770.610075      0
# 957      Wandsworth  2022  630159.666667      0
# 721          Newham  1996   55747.012583      0
# 223         Croydon  2008  235998.602192      0
# 886   Tower Hamlets  2011  287262.479150      0
# 192  City of London  2007  433838.474217      0

# %%
type(Average_price)
# Out:
# pandas.core.frame.DataFrame

# %%
Average_price["year"].dtype
# Out:
# dtype('int32')

# %%
Average_price["year"]== 1995
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# Name: year, Length: 990, dtype: bool

# %%
item
# Out:
# 'City of London'

# %%
(Average_price["London Borough"]== item).unique()
# Out:
# array([False,  True])

# %%
((Average_price["London Borough"]== item) & (Average_price["year"]== 1995)).sum()
# Out:
# 1

# %%
Average_price.loc[(Average_price["London Borough"]== item) & (Average_price["year"]== 1995), 'price'].values[0]
# Out:
# 133689.23303333335

# %%
for item in London_Borough:
    Average_price.loc[Average_price["London Borough"]== item,"ratio"] = Average_price.loc[Average_price["London Borough"]== item, "price"] \
            / Average_price.loc[(Average_price["London Borough"]== item) & (Average_price["year"]== 1995), 'price'].values[0]

# %%
Average_price
# Out:
#          London Borough  year         price     ratio
# 0    Barking & Dagenham  1995  5.181797e+04  1.000000
# 1    Barking & Dagenham  1996  5.171819e+04  0.998074
# 2    Barking & Dagenham  1997  5.597426e+04  1.080209
# 3    Barking & Dagenham  1998  6.028582e+04  1.163415
# 4    Barking & Dagenham  1999  6.532093e+04  1.260585
# ..                  ...   ...           ...       ...
# 985         Westminster  2020  9.617118e+05  7.193637
# 986         Westminster  2021  1.025339e+06  7.669571
# 987         Westminster  2022  1.090405e+06  8.156267
# 988         Westminster  2023  1.093584e+06  8.180045
# 989         Westminster  2024  9.367150e+05  7.006660
#
# [990 rows x 4 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
